# %% [markdown]
# <a href="https://colab.research.google.com/github/himesh8700/data_science/blob/main/Colab/Test.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("hello")
# Out:
# hello

# %%
from google.colab import files

uploaded = files.upload()
# Out:
#      <input type="file" id="files-8eb0f690-32fe-47fd-8432-8e478ef42b0d" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-8eb0f690-32fe-47fd-8432-8e478ef42b0d">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving stock.csv to stock.csv

# %%
import pandas as pd

# %%
pd.read_csv("stock.csv")
# Out:
#         Symbol       Open  ... 365 Days % Change 30 Days % Change
# 0     NIFTY 50  14,888.60  ...             24.41             4.02
# 1    NESTLEIND  16,050.50  ...             -1.02            -8.35
# 2         NTPC      107.1  ...             -1.92            17.20
# 3      SBILIFE        860  ...             -3.07            -2.02
# 4       MARUTI   6,900.00  ...              9.88           -12.96
# 5      DRREDDY   4,460.00  ...             43.95            -9.82
# 6    BRITANNIA   3,389.00  ...             10.49            -6.93
# 7   HINDUNILVR   2,158.00  ...             -4.85           -11.02
# 8        TITAN   1,420.00  ...             12.34            -2.13
# 9         INFY   1,269.00  ...             59.95            -3.77
# 10     HCLTECH        908  ...             56.10            -4.66
# 11    DIVISLAB   3,419.50  ...             57.04            -3.42
# 12   SUNPHARMA     604.95  ...             58.91             4.50
# ...
